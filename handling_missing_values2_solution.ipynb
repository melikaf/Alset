# %% [markdown]
# <a href="https://colab.research.google.com/github/melikaf/Alset/blob/master/handling_missing_values2_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Handling Missing Values 2

# %%
#walkthrough

# %%
#Solution

def replace_missing_values_function(x):
  import pandas as pd
  x = x.fillna(x.mean())
#   This is not the optimal solution
#   from sklearn.preprocessing import Imputer
#   impute = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
#   x = impute.fit_transform(x)
  return x

# %%
# Tests 
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
import pandas as pd
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1bpTtTaZhH1l2cGRQhbi9IaOnprvjKDIu0nGy597lXm0/gviz/tq?tqx=out:csv&sheet=personal_data')
df = replace_missing_values_function(df)
df = pd.DataFrame(df)

# %%
assert df.isnull().any().any() == False, "Missing Values not removed"
